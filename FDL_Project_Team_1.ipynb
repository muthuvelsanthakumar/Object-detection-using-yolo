# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 881.3/881.3 kB 6.9 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# Build a YOLOv9c model from pretrained weight
model = YOLO('yolov9c.pt')

# Run inference
results = model('yf.mp4', save=True)
# Out:
# ...
# 100%|██████████| 49.4M/49.4M [00:00<00:00, 173MB/s]
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/334) /content/yf.mp4: 384x640 9 persons, 3 bicycles, 8 cars, 5 traffic lights, 1 fire hydrant, 1496.8ms
# video 1/1 (frame 2/334) /content/yf.mp4: 384x640 9 persons, 3 bicycles, 8 cars, 5 traffic lights, 1 fire hydrant, 1474.1ms
# video 1/1 (frame 3/334) /content/yf.mp4: 384x640 10 persons, 3 bicycles, 9 cars, 4 traffic lights, 1 fire hydrant, 1507.3ms
# ...
